# %% [markdown]
# # 附录：深度学习工具
# :label:`chap_appendix_tools`
#
# 为了充分利用《动手学深度学习》，本书将在本附录中介绍不同工具，
# 例如如何运行这本交互式开源书籍和为本书做贡献。
#
# :begin_tab:toc
#  - [01-jupyter](01-jupyter.ipynb)
#  - [02-sagemaker](02-sagemaker.ipynb)
#  - [03-aws](03-aws.ipynb)
#  - [04-selecting-servers-gpus](04-selecting-servers-gpus.ipynb)
#  - [05-contributing](05-contributing.ipynb)
#  - [06-d2l](06-d2l.ipynb)
# :end_tab:
